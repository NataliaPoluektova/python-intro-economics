# %% [markdown]
# # Практична робота №1
# **Тема:** Вступ до Python. Налаштування середовища та виконання першого завдання
#
# ## Мета роботи
# 1. Ознайомитися з основами роботи в середовищі програмування Python.
# 2. Навчитися запускати прості програми та зберігати результати роботи.
# 3. Освоїти базові операції введення, виведення та обчислення в Python.
# 4. Навчитися надавати результати викладачу у зручному форматі.

# %% [markdown]
# ## Крок 1. Перша програма
# У клітинці нижче напишіть програму, яка виведе повідомлення:
#
# `Привіт, я починаю програмувати на Python!`

# %%
# Ваш код тут
print("...")

# %% [markdown]
# ## Завдання 1. Арифметичні обчислення
# Напишіть програму, яка:
# - зберігає у змінних `a` і `b` два числа (наприклад, 125 і 375);
# - обчислює їхню суму, різницю, добуток і частку;
# - виводить результати на екран.

# %%
# Ваш код тут
a = ...
b = ...

сума = ...
різниця = ...
добуток = ...
частка = ...

print("Сума:", сума)
print("Різниця:", різниця)
print("Добуток:", добуток)
print("Частка:", частка)

# %% [markdown]
# ## Завдання 2. Економічна задача (точка беззбитковості)
# Фірма виробляє продукцію з такими параметрами:
# - постійні витрати = 10000 грн
# - змінні витрати на одиницю продукції = 50 грн
# - ціна продажу однієї одиниці = 80 грн
#
# Необхідно розрахувати точку беззбитковості (кількість продукції, яку потрібно продати, щоб прибуток дорівнював нулю).
#
# **Формула:**
#
# $$
# Q = \frac{FC}{P - VC}
# $$
#
# де
# - $Q$ – точка беззбитковості (кількість одиниць),
# - $FC$ – постійні витрати,
# - $P$ – ціна продажу,
# - $VC$ – змінні витрати на одиницю.

# %%
# Ваш код тут
FC = 10000
VC = 50
P = 80

Q = ... # розрахуйте за формулою
print("Точка беззбитковості:", Q, "одиниць продукції")

# %% [markdown]
# ## Завдання 3. Індивідуальний варіант
# Кожен студент змінює значення параметрів задачі 2:
# - Постійні витрати = (остання цифра вашого студентського квитка × 1000) + 5000
# - Змінні витрати = (передостання цифра студентського квитка × 5) + 30
# - Ціна продажу = змінні витрати + (10–20 грн на ваш вибір)
#
# Розрахуйте власну точку беззбитковості.

# %%
# Ваш код тут
FC = ...
VC = ...
P = ...

Q = ...
print("Моя точка беззбитковості:", Q, "одиниць продукції")

# %% [markdown]
# ## Як здати роботу викладачу
# 1. Завершіть усі завдання.
# 2. Оберіть **File → Download → Download .ipynb** (щоб здати блокнот із кодом).
# 3. Або оберіть **File → Download → Download .pdf** (щоб здати у вигляді готового звіту).
# 4. Надішліть файл викладачу (електронна пошта або LMS).

# %% [markdown]
# ## Контрольні питання
# 1. Що таке Python і для чого його використовують у економіці?
# 2. Які середовища можна використати для запуску Python-коду?
# 3. Як у Python вивести повідомлення на екран?
# 4. У чому полягає економічний зміст задачі про точку беззбитковості?
